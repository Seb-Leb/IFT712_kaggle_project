# %%
''' Python packages '''
import numpy as np
from matplotlib import pyplot as plt

''' Project specific tools '''
from data_management import *
from models import *
from display import *

''' Display configs '''
# %matplotlib inline
plt.rcParams['figure.figsize'] = (14.0, 8.0) # set default size of plots

# %%
# %load_ext autoreload
# %autoreload 2

# %%
data_man = DataManager('BioPlex_PU_data.pkl')

# %%
P, U, _, _ = data_man.parse_pickle()

# %%
fig = FigureDrawer()

# %%
X = np.concatenate((P, U), axis=0)

# %%
X_norm = data_man.normalize(X)

# %%
t = np.concatenate(([1,]*len(P), [0,]*len(U)), axis=0)

# %%
fig.draw_hist_array(X_norm.T)

# %%
import seaborn as sns

# %%
import random

# %%
from MulticoreTSNE import MulticoreTSNE as TSNE

# %%
tsne = TSNE(n_jobs=6, n_components=3, perplexity=50, learning_rate=150)

# %%
n_sample = int(X_norm.shape[0]*.01)
x_sampl = np.array(random.sample(list(X_norm), n_sample))
x_sampl.shape
# Out:
# (3712, 9)

# %%
X_embedded = tsne.fit_transform(X_norm)

# %%
X_tsne = X_embedded[::-1]

# %%
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=t, legend='full', alpha=0.5)
